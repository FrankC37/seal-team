# %%
import pandas as pd
from datetime import datetime   
#Declaring Variables that are hard coded

#This file is used for sending output data
writer = pd.ExcelWriter(r'C:\Users\fconiglio\Dropbox (USA Sealing)\USA Sealing Team Folder\USA Sealing Inc\Frank\Access_Output.xlsx', engine='xlsxwriter')
#This file is used for the input data to be sorted
shipfile = r"C:\Users\fconiglio\Dropbox (USA Sealing)\USA Sealing Team Folder\USA Sealing Inc\Frank\ShipPick_FC_Best.xlsx"
fullship = r"C:\Users\fconiglio\Dropbox (USA Sealing)\USA Sealing Team Folder\USA Sealing Inc\USAS Reports\Shipping\Ship Report V9 11.4.0.xlsx"

#Reading in the hard coded file
df = pd.read_excel(fullship,sheet_name=6)

# Converting Date Columns to Date format in pandas and using datetime library to format 
df["Order Date"] = pd.to_datetime(df["Order Date"])
df["Requested Ship Date By"] = pd.to_datetime(df["Requested Ship Date By"], errors= 'coerce')
#This column needs the coerce tag becuase of some errors with the formula converting into a value (I think)
df["Required Ship by 4795"] = pd.to_datetime(df["Required Ship by 4795"], errors= 'coerce')
df["Order Date"] = df["Order Date"].dt.strftime('%m/%d/%Y')
df["Requested Ship Date By"] = df["Requested Ship Date By"].dt.strftime('%m/%d/%Y')
df["Required Ship by 4795"] = df["Required Ship by 4795"].dt.strftime('%m/%d/%Y')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\core\arrays\datetimes.py in objects_to_datetime64ns(data, dayfirst, yearfirst, utc, errors, require_iso8601, allow_object, allow_mixed)
#    2186         try:
# -> 2187             values, tz_parsed = conversion.datetime_to_datetime64(data.ravel("K"))
#    2188             # If tzaware, these values represent unix timestamps, so we
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\_libs\tslibs\conversion.pyx in pandas._libs.tslibs.conversion.datetime_to_datetime64()
#
# TypeError: Unrecognized value type: <class 'str'>
#
# During handling of the above exception, another exception occurred:
#
# ParserError                               Traceback (most recent call last)
# ...

# %%
#declaring data frames for Branch and Drop ship prio
branch_drop_prio_sw = df[(df[' Grainger Final Tag'] == 'Branch In Time')|(df[' Grainger Final Tag'] == 'Drop Ship in Time') & 
(df['Days Left Before Late ( value of -2 is Tomorrow, value of 1 is today, value of 2 is yesterday)'] > -12)& 
(df['Printed'] != 'Yes, Printed')& (df['WIP/Blank'] != 'Needs Review') & (df['DY/SW'] == 'SW') ]

branch_drop_prio_dy = df[(df[' Grainger Final Tag'] == 'Branch In Time')|(df[' Grainger Final Tag'] == 'Drop Ship in Time') & 
(df['Days Left Before Late ( value of -2 is Tomorrow, value of 1 is today, value of 2 is yesterday)'] > -12)& 
(df['Printed'] != 'Yes, Printed')& (df['WIP/Blank'] != 'Needs Review') & (df['DY/SW'] == 'DY') ]

#Declaring data frames for DC prio
dc_prio_sw = df[(df[' Grainger Final Tag'] == 'DC Branch In Time')& 
(df['Printed'] != 'Yes, Printed')& (df['WIP/Blank'] != 'Needs Review') & (df['DY/SW'] == 'SW')] 

dc_prio_dy = df[(df[' Grainger Final Tag'] == 'DC Branch In Time') & 
(df['Printed'] != 'Yes, Printed')& (df['WIP/Blank'] != 'Needs Review') & (df['DY/SW'] == 'DY')] 

#Declaring Data Frames for OOLT Branch and Drop Ship
branch_drop_oolt_sw = df[(df[' Grainger Final Tag'] == 'Branch Late')|(df[' Grainger Final Tag'] == 'Drop Ship Late')& 
(df['Printed'] != 'Yes, Printed')& (df['WIP/Blank'] != 'Needs Review') & (df['DY/SW'] == 'SW') ]

branch_drop_oolt_dy = df[(df[' Grainger Final Tag'] == 'Branch Late')|(df[' Grainger Final Tag'] == 'Drop Ship Late')& 
(df['Printed'] != 'Yes, Printed')& (df['WIP/Blank'] != 'Needs Review') & (df['DY/SW'] == 'DY') ]


#Declaring Data Frames for OOLT DC
dc_oolt_sw = df[(df[' Grainger Final Tag'] == 'DC Branch Late')& 
(df['Printed'] != 'Yes, Printed')& (df['WIP/Blank'] != 'Needs Review') & (df['DY/SW'] == 'SW') ]

dc_oolt_dy = df[(df[' Grainger Final Tag'] == 'Branch Late')& 
(df['Printed'] != 'Yes, Printed')& (df['WIP/Blank'] != 'Needs Review') & (df['DY/SW'] == 'DY') ]

#Declaring Amazon Priority data frames
amazon_prio_sw = df[(df['Amazon Final Tag'] == 'In Lead Time') & 
(df['Days Left Before Late ( value of -2 is Tomorrow, value of 1 is today, value of 2 is yesterday)'] > -12)& 
(df['Printed'] != 'Yes, Printed')& (df['WIP/Blank'] != 'Needs Review') & (df['DY/SW'] == 'SW')] 

amazon_prio_dy = df[(df['Amazon Final Tag'] == 'In Lead Time') & 
(df['Days Left Before Late ( value of -2 is Tomorrow, value of 1 is today, value of 2 is yesterday)'] > -12)& 
(df['Printed'] != 'Yes, Printed')& (df['WIP/Blank'] != 'Needs Review') & (df['DY/SW'] == 'DY')] 



#Writing the data frames to the writer hard coded file

branch_drop_prio_sw.to_excel(writer,sheet_name='G_Prio_SW', index=False)
branch_drop_prio_dy.to_excel(writer,sheet_name='G_Prio_DY', index=False)
dc_prio_sw.to_excel(writer,sheet_name='G_Prio_DC_SW', index=False)
dc_prio_dy.to_excel(writer,sheet_name='G_Prio_DC_DY', index=False)
amazon_prio_sw.to_excel(writer,sheet_name='Amazon_Prio_SW', index=False)
amazon_prio_dy.to_excel(writer,sheet_name='Amazon_Prio_DY', index=False)
branch_drop_oolt_sw.to_excel(writer,sheet_name='G_OOLT_SW', index=False)
branch_drop_oolt_dy.to_excel(writer,sheet_name='G_OOLT_DY', index=False)
dc_oolt_sw.to_excel(writer,sheet_name='G_OOLT_DC_SW', index=False)
dc_oolt_dy.to_excel(writer,sheet_name='G_OOLT_DC_DY', index=False)


#Closing/saving the file
writer.save()
