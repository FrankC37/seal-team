# %%
import pandas as pd

allitems = pd.read_excel('Converting Data.xlsx',0)
parents_passthrough = pd.read_excel('Converting Data.xlsx',1)
converting = pd.read_excel('Converting Data.xlsx',2)
assembly = pd.read_excel('Converting Data.xlsx',3)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# C:\Users\FCONIG~1\AppData\Local\Temp/ipykernel_13020/1533905140.py in <module>
#       2
#       3 allitems = pd.read_excel('Converting Data.xlsx',0)
# ----> 4 parents_passthrough = pd.read_excel('Converting Data.xlsx',1,index=0)
#       5 converting = pd.read_excel('Converting Data.xlsx',2,index=0)
#       6 assembly = pd.read_excel('Converting Data.xlsx',3)
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# TypeError: read_excel() got an unexpected keyword argument 'index'

# %%
converting
# Out:
#                      1                                                  2   \
# 0            Product ID                                        Description
# 1           ZUSA-HT-721  FDA Silicone Tubing - Clear - 1/16" ID x 1/8" ...
# 2           ZUSA-HT-722  FDA Silicone Tubing - Clear - 1/16" ID x 3/16"...
# 3          ZUSA-HT-3042  FDA Silicone Tubing - Clear - 3/32" ID x 7/32"...
# 4           ZUSA-HT-723  FDA Silicone Tubing - Clear - 1/8" ID x 3/16" ...
# ...                 ...                                                ...
# 36894  BULK-PS-EPTFE-60  Compressible ePTFE Plastic Sheet - 1/64" Thick...
# 36895    BULK-RS-P60-69  Polyurethane Strip No Adhesive - 60A - 1/2" Th...
# 36896    BULK-RS-P60-68  Polyurethane Strip No Adhesive - 60A - 1/2" Th...
# 36897    BULK-RS-P60-70  Polyurethane Strip No Adhesive - 60A - 1/2" Th...
# 36898    BULK-RS-P60-74  Polyurethane Strip No Adhesive - 60A - 1/2" Th...
#
# ...
